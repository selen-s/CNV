# %% [markdown]
# ## CNV For Deep Space Adaptation - Inertial Navigation

# %% [markdown]
# This version of CNV has been adapted to calculate positions relative to stars, and is intended for use not on Earth.

# %%
import numpy as np

# %% [markdown]
# ## Step 1: Process Timeseries Star Images

# %% [markdown]
# ## Step 2: Calculate Parallax Differences from "known" state to "new" state

# %% [markdown]
# ### Step 2.5: Represent Parallax Differences on Lie Group State Space

# %% [markdown]
# ## Step 3: Apply KF to generate a "delta" trajectory and add on to the previously created map

# %% [markdown]
# ## Step 4: Visualize Map by Updating Trajectory in Real Time Relative to initial starting position (there is no way to tell the absolute location yet unless provided as an IC)
